# %%
#Importar librerias:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Importar y mostrar datos:
datos = pd.read_csv("Ansiedad.csv", sep = ";")
#Intenta cargar el archivo CSV 
datos
# Out:
#     Gender:                Age:     Educational Level  \
# 0      Male      19 to 24 years  College - Bachelor's
# 1      Male      19 to 24 years  College - Bachelor's
# 2    Female    18 years or less           High School
# 3    Female    18 years or less           High School
# 4      Male    18 years or less           High School
# ..      ...                 ...                   ...
# 347  Female      19 to 24 years  College - Bachelor's
# 348  Female  25 years and above  College - Bachelor's
# 349  Female      19 to 24 years  College - Bachelor's
# 350  Female  25 years and above  College - Bachelor's
# 351  Female    18 years or less           High School
#
#      Little interest or pleasure in doing things   \
# 0                                               3
# 1                                               2
# 2                                               2
# 3                                               3
# 4                                               1
# ...
